# %% [markdown]
# `chain_samples()` function in [cDNA_Cupcake](https://github.com/Magdoll/cDNA_Cupcake) crashes with an out-of-memory error on some of my samples.  Try as I might, I've not been able to decode exactly what and why it does what it does (why does it write *everything* to a file and read it back in?).  However, I found that the [pyranges](https://github.com/biocore-ntnu/pyranges) module has a `cluster` function that will give a common id to overlapping sequences.  Need to see if that will work.

# %%
import pyranges as pr
import pandas as pd
from pathlib import Path

# %%
bc1001_gff = Path("test_data/bc1001/repaired.sample.gff")
bc1002_gff = Path("test_data/bc1002/repaired.sample.gff")
gencode_v37_gff = Path("test_data/gencode.v37.annotation.gtf.gz")

# %%
bc1001_annot = pr.read_gff(bc1001_gff)

# %%
bc1001_annot
# Out:
# +--------------+------------+--------------+-----------+-----------+------------+--------------+------------+------------+-----------------+
# | Chromosome   | Source     | Feature      | Start     | End       | Score      | Strand       | Frame      | gene_id    | transcript_id   |
# | (category)   | (object)   | (category)   | (int32)   | (int32)   | (object)   | (category)   | (object)   | (object)   | (object)        |
# |--------------+------------+--------------+-----------+-----------+------------+--------------+------------+------------+-----------------|
# | chr1         | PacBio     | transcript   | 1389718   | 1394777   | .          | +            | .          | PB.3       | PB.3.1          |
# | chr1         | PacBio     | exon         | 1389718   | 1390368   | .          | +            | .          | PB.3       | PB.3.1          |
# | chr1         | PacBio     | exon         | 1390455   | 1390565   | .          | +            | .          | PB.3       | PB.3.1          |
# | chr1         | PacBio     | exon         | 1390767   | 1394777   | .          | +            | .          | PB.3       | PB.3.1          |
# | ...          | ...        | ...          | ...       | ...       | ...        | ...          | ...        | ...        | ...             |
# | chrX         | PacBio     | exon         | 154790982 | 154791068 | .          | -            | .          | PB.3323    | PB.3323.1       |
# | chrX         | PacBio     | exon         | 154791768 | 154791847 | .          | -            | .          | PB.3323    | PB.3323.1       |
# | chrX         | PacBio     | exon         | 154792141 | 154792285 | .          | -            | .          | PB.3323    | PB.3323.1       |
# | chrX         | PacBio     | exon         | 154805271 | 154805472 | .          | -            | .          | PB.3323    | PB.3323.1       |
# +--------------+------------+--------------+-----------+-----------+------------+--------------+------------+------------+-----------------+
# Stranded PyRanges object has 208,502 rows and 10 columns from 23 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.

# %%
bc1002_annot = pr.read_gff(bc1002_gff)
# gencode = pr.read_gff(gencode_v37_gff)

# %%
# gencode

# %%
# gencode.subset(lambda x: x["Feature"].isin(("transcript", "exon")))

# %%
# gencode_expressed = gencode.subset(lambda x: x["Feature"].isin(("transcript", "exon")))

# %%
bc1001_sample_name = pd.Series(["bc1001" for _ in range(len(bc1001_annot))], name="sample_source")
bc1001_annot = bc1001_annot.insert(bc1001_sample_name)

# %%
bc1001_annot.head()
# Out:
# +--------------+------------+--------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------------+
# | Chromosome   | Source     | Feature      |     Start |       End | Score      | Strand       | Frame      | gene_id    | transcript_id   | sample_source   |
# | (category)   | (object)   | (category)   |   (int32) |   (int32) | (object)   | (category)   | (object)   | (object)   | (object)        | (object)        |
# |--------------+------------+--------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------------|
# | chr1         | PacBio     | transcript   |   1389718 |   1394777 | .          | +            | .          | PB.3       | PB.3.1          | bc1001          |
# | chr1         | PacBio     | exon         |   1389718 |   1390368 | .          | +            | .          | PB.3       | PB.3.1          | bc1001          |
# | chr1         | PacBio     | exon         |   1390455 |   1390565 | .          | +            | .          | PB.3       | PB.3.1          | bc1001          |
# | chr1         | PacBio     | exon         |   1390767 |   1394777 | .          | +            | .          | PB.3       | PB.3.1          | bc1001          |
# | chr1         | PacBio     | transcript   |   2133700 |   2139625 | .          | +            | .          | PB.7       | PB.7.1          | bc1001          |
# | chr1         | PacBio     | exon         |   2133700 |   2139625 | .          | +            | .          | PB.7       | PB.7.1          | bc1001          |
# | chr1         | PacBio     | transcript   |   2245074 |   2280214 | .          | +            | .          | PB.8       | PB.8.1          | bc1001          |
# | chr1         | PacBio     | exon         |   2245074 |   2245959 | .          | +            | .          | PB.8       | PB.8.1          | bc1001          |
# +--------------+------------+--------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------------+
# Stranded PyRanges object has 8 rows and 11 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.

# %%
bc1002_sample_name = pd.Series(["bc1002" for _ in range(len(bc1002_annot))], name="sample_source")
bc1002_annot = bc1002_annot.insert(bc1002_sample_name)

# %%
bc1001_1002 = bc1001_annot.join(bc1002_annot, how="left", nb_cpu=4)
# Out:
# 2021-04-30 15:37:30,790	INFO services.py:1171 -- View the Ray dashboard at http://127.0.0.1:8265

# %% [markdown]
# Note: one issue here is that `join()` has to perform some sort of table join, it won't simply bind rows.  This necessarily means we are going to lose samples that are not present in both PyRanges objects.
#
# We could probably deal with this by performing multiple joins or, if nothing else, one can probably get around this by taking all the underlying dataframes, merging those together, converting to a `dict`, and then converting that back into a `PyRanges` object

# %%
bc1001_1002.head()
# Out:
# +--------------+------------+------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------------+------------+-------------+-----------+-----------+------------+--------------+------------+-------+
# | Chromosome   | Source     | Feature    |     Start |       End | Score      | Strand       | Frame      | gene_id    | transcript_id   | sample_source   | Source_b   | Feature_b   |   Start_b |     End_b | Score_b    | Strand_b     | Frame_b    | +3    |
# | (category)   | (object)   | (object)   |   (int64) |   (int64) | (object)   | (category)   | (object)   | (object)   | (object)        | (object)        | (object)   | (object)    |   (int64) |   (int64) | (object)   | (category)   | (object)   | ...   |
# |--------------+------------+------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------------+------------+-------------+-----------+-----------+------------+--------------+------------+-------|
# | chr1         | PacBio     | transcript |   1389718 |   1394777 | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | transcript  |   1385709 |   1399339 | .          | -            | .          | ...   |
# | chr1         | PacBio     | transcript |   1389718 |   1394777 | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | transcript  |   1386500 |   1399317 | .          | -            | .          | ...   |
# | chr1         | PacBio     | transcript |   1389718 |   1394777 | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | transcript  |   1386504 |   1399338 | .          | -            | .          | ...   |
# | chr1         | PacBio     | transcript |   1389718 |   1394777 | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | transcript  |   1386705 |   1399338 | .          | -            | .          | ...   |
# | chr1         | PacBio     | transcript |   1389718 |   1394777 | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | transcript  |   1386709 |   1399328 | .          | -            | .          | ...   |
# | chr1         | PacBio     | transcript |   1389718 |   1394777 | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | transcript  |   1386710 |   1399335 | .          | -            | .          | ...   |
# | chr1         | PacBio     | transcript |   1389718 |   1394777 | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | transcript  |   1386710 |   1399317 | .          | -            | .          | ...   |
# | chr1         | PacBio     | transcript |   1389718 |   1394777 | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | transcript  |   1387343 |   1399317 | .          | -            | .          | ...   |
# +--------------+------------+------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------------+------------+-------------+-----------+-----------+------------+--------------+------------+-------+
# Stranded PyRanges object has 8 rows and 21 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 3 hidden columns: gene_id_b, transcript_id_b, sample_source_b

# %%
bc1001_1002.cluster().subset(lambda x: x.Cluster == 1)
# Out:
# +--------------+------------+------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------------+------------+-------------+-----------+-----------+------------+--------------+------------+-------+
# | Chromosome   | Source     | Feature    | Start     | End       | Score      | Strand       | Frame      | gene_id    | transcript_id   | sample_source   | Source_b   | Feature_b   | Start_b   | End_b     | Score_b    | Strand_b     | Frame_b    | +4    |
# | (category)   | (object)   | (object)   | (int64)   | (int64)   | (object)   | (category)   | (object)   | (object)   | (object)        | (object)        | (object)   | (object)    | (int64)   | (int64)   | (object)   | (category)   | (object)   | ...   |
# |--------------+------------+------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------------+------------+-------------+-----------+-----------+------------+--------------+------------+-------|
# | chr1         | PacBio     | transcript | 1389718   | 1394777   | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | transcript  | 1385709   | 1399339   | .          | -            | .          | ...   |
# | chr1         | PacBio     | transcript | 1389718   | 1394777   | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | exon        | 1390765   | 1392803   | .          | -            | .          | ...   |
# | chr1         | PacBio     | transcript | 1389718   | 1394777   | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | exon        | 1390765   | 1392803   | .          | -            | .          | ...   |
# | chr1         | PacBio     | transcript | 1389718   | 1394777   | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | exon        | 1393395   | 1393460   | .          | -            | .          | ...   |
# | ...          | ...        | ...        | ...       | ...       | ...        | ...          | ...        | ...        | ...             | ...             | ...        | ...         | ...       | ...       | ...        | ...          | ...        | ...   |
# | chr1         | PacBio     | exon       | 1390767   | 1394777   | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | transcript  | 1390334   | 1399339   | .          | -            | .          | ...   |
# | chr1         | PacBio     | exon       | 1390767   | 1394777   | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | exon        | 1390765   | 1392803   | .          | -            | .          | ...   |
# | chr1         | PacBio     | exon       | 1390767   | 1394777   | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | exon        | 1390765   | 1392803   | .          | -            | .          | ...   |
# | chr1         | PacBio     | exon       | 1390767   | 1394777   | .          | +            | .          | PB.3       | PB.3.1          | bc1001          | PacBio     | transcript  | 1386710   | 1399335   | .          | -            | .          | ...   |
# +--------------+------------+------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------------+------------+-------------+-----------+-----------+------------+--------------+------------+-------+
# Stranded PyRanges object has 108 rows and 22 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 4 hidden columns: gene_id_b, transcript_id_b, sample_source_b, Cluster

# %%
len(bc1001_1002)
# Out:
# 5311945

# %%
len(bc1001_annot)
# Out:
# 208502

# %%
len(bc1002_annot)
# Out:
# 172893

# %% [markdown]
# Not sure why there are ~20-50 times as many rows in the merged set as there are in the two parental non-merged objects.
#
# Another way of doing this would be to concatinate the files and then import and cluster.

# %%
bc1001_annot.to_gff3(path="alt_bc1001.gff3")

# %%
bc1002_annot.to_gff3(path="alt_bc1002.gff3")

# %%
bc1001_sample_name = pd.Series(["bc1001" for _ in range(len(bc1001_annot))], name="Source")

# %%
bc1001_annot.drop("sample_source").insert(bc1001_sample_name).to_gff3(path="alt_bc1001.gff3")

# %%
bc1002_sample_name = pd.Series(["bc1002" for _ in range(len(bc1002_annot))], name="Source")

# %%
bc1002_annot.drop("sample_source").insert(bc1002_sample_name).to_gff3(path="alt_bc1002.gff3")

# %%
# !cat alt_bc1001.gff3 alt_bc1002.gff3 > bc1001-bc1002-merged.gff3

# %%
merged = pr.read_gtf("/home/milo/workspace/cdna_brownie/notebooks/test_data/all-merged.gff")

# %% [markdown]
# Some of the clusters appear to have **very** cover very wide intervals, to the point where I'm not conviced these should "cluster".
#
# For instance, bc1001/PB.13 bc1002/PB.7:

# %%
merged.subset(lambda x: x.Source == "bc1004").subset(lambda y: y.gene_id == "PB.13")
# Out:
# +--------------+------------+--------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------+-----------+
# | Chromosome   | Source     | Feature      |     Start |       End | Score      | Strand       | Frame      | gene_id    | transcript_id   |   Cluster |     Count |
# | (category)   | (object)   | (category)   |   (int32) |   (int32) | (object)   | (category)   | (object)   | (object)   | (object)        |   (int32) |   (int64) |
# |--------------+------------+--------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------+-----------|
# | chr1         | bc1004     | transcript   |   2556370 |   2563747 | .          | +            | .          | PB.13      | PB.13.2         |         2 |        44 |
# | chr1         | bc1004     | transcript   |   2555793 |   4508611 | .          | +            | .          | PB.13      | PB.13.1         |         2 |        44 |
# +--------------+------------+--------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------+-----------+
# Stranded PyRanges object has 2 rows and 12 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.

# %%
merged.subset(lambda x: x.Source == "bc1019").subset(lambda y: y.gene_id == "PB.7")
# Out:
# +--------------+------------+--------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------+-----------+
# | Chromosome   | Source     | Feature      |     Start |       End | Score      | Strand       | Frame      | gene_id    | transcript_id   |   Cluster |     Count |
# | (category)   | (object)   | (category)   |   (int32) |   (int32) | (object)   | (category)   | (object)   | (object)   | (object)        |   (int32) |   (int64) |
# |--------------+------------+--------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------+-----------|
# | chr1         | bc1019     | transcript   |   3857266 |   3885426 | .          | +            | .          | PB.7       | PB.7.1          |         2 |        44 |
# +--------------+------------+--------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------+-----------+
# Stranded PyRanges object has 1 rows and 12 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.

# %% [markdown]
# This makes a bit more sense now: bc1004 PB.13.2 is a subset of PB.13.1 and bc1019 PB.7.1 is a subset of bc1004 PB.13.2

# %% [markdown]
# So, to summarize what we need to do:
#
# 1) In each GFF, change the "Source" field to the sample name.
# 2) Concatinate all GFFs.
# 3) Cluster the transcripts/exons in the merged PyRanges object.
# 4) Create a new PBID based on the cluster number and use this to convert the existing gene_id and transcript_ids.
# 5) For each distinct "Source", we need to create a translation table mapping the previous gene_is/transcript_id and the new cluster-based ones.
# 6) Convert the ids in the other associated files (i.e. the abundance and group files) for each sample

# %%
prdf = merged.as_df()

# %%
pr_dict = prdf.to_dict()

# %%
pd.DataFrame(data = pr_dict)
# Out:
#        Chromosome  Source     Feature     Start       End Score Strand Frame  \
# 0            chr1  bc1004  transcript    833846    838936     .      +     .
# 1            chr1  bc1003  transcript    827658    857173     .      +     .
# 2            chr1  bc1002  transcript    854801    859446     .      +     .
# 3            chr1  bc1005  transcript    834239    838441     .      +     .
# 4            chr1  bc1004  transcript   2556370   2563747     .      +     .
# ...           ...     ...         ...       ...       ...   ...    ...   ...
# 175277       chrY  bc1012  transcript  19684562  19744726     .      -     .
# 175278       chrY  bc1012  transcript  19684566  19744723     .      -     .
# 175279       chrY  bc1012  transcript  19705423  19744726     .      -     .
# 175280       chrY  bc1012  transcript  19705425  19744723     .      -     .
# 175281       chrY  bc1012  transcript  19705601  19744714     .      -     .
#
#         gene_id transcript_id  Cluster  Count
# 0          PB.3        PB.3.1        1      4
# 1          PB.2        PB.2.1        1      4
# 2          PB.2        PB.2.1        1      4
# 3          PB.1        PB.1.1        1      4
# 4         PB.13       PB.13.2        2     44
# ...         ...           ...      ...    ...
# 175277  PB.3466     PB.3466.1     3836      5
# 175278  PB.3466     PB.3466.2     3836      5
# 175279  PB.3466     PB.3466.3     3836      5
# 175280  PB.3466     PB.3466.4     3836      5
# 175281  PB.3466     PB.3466.5     3836      5
#
# [175282 rows x 12 columns]

# %%
pr.from_dict(pr_dict)
# Out:
# +--------------+------------+------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------+-----------+
# | Chromosome   | Source     | Feature    | Start     | End       | Score      | Strand       | Frame      | gene_id    | transcript_id   | Cluster   | Count     |
# | (category)   | (object)   | (object)   | (int32)   | (int32)   | (object)   | (category)   | (object)   | (object)   | (object)        | (int64)   | (int64)   |
# |--------------+------------+------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------+-----------|
# | chr1         | bc1004     | transcript | 833846    | 838936    | .          | +            | .          | PB.3       | PB.3.1          | 1         | 4         |
# | chr1         | bc1003     | transcript | 827658    | 857173    | .          | +            | .          | PB.2       | PB.2.1          | 1         | 4         |
# | chr1         | bc1002     | transcript | 854801    | 859446    | .          | +            | .          | PB.2       | PB.2.1          | 1         | 4         |
# | chr1         | bc1005     | transcript | 834239    | 838441    | .          | +            | .          | PB.1       | PB.1.1          | 1         | 4         |
# | ...          | ...        | ...        | ...       | ...       | ...        | ...          | ...        | ...        | ...             | ...       | ...       |
# | chrY         | bc1012     | transcript | 19684566  | 19744723  | .          | -            | .          | PB.3466    | PB.3466.2       | 3836      | 5         |
# | chrY         | bc1012     | transcript | 19705423  | 19744726  | .          | -            | .          | PB.3466    | PB.3466.3       | 3836      | 5         |
# | chrY         | bc1012     | transcript | 19705425  | 19744723  | .          | -            | .          | PB.3466    | PB.3466.4       | 3836      | 5         |
# | chrY         | bc1012     | transcript | 19705601  | 19744714  | .          | -            | .          | PB.3466    | PB.3466.5       | 3836      | 5         |
# +--------------+------------+------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------+-----------+
# Stranded PyRanges object has 175,282 rows and 12 columns from 35 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.

# %%
merged2 = merged.copy()

# %%
merged2 = merged2.insert(pd.Series(["stuff" for _ in range(len(merged2.as_df()))], name="Source"))
merged2.head()
# Out:
# +--------------+------------+--------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------+-----------+
# | Chromosome   | Source     | Feature      |     Start |       End | Score      | Strand       | Frame      | gene_id    | transcript_id   |   Cluster |     Count |
# | (category)   | (object)   | (category)   |   (int32) |   (int32) | (object)   | (category)   | (object)   | (object)   | (object)        |   (int32) |   (int64) |
# |--------------+------------+--------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------+-----------|
# | chr1         | stuff      | transcript   |    833846 |    838936 | .          | +            | .          | PB.3       | PB.3.1          |         1 |         4 |
# | chr1         | stuff      | transcript   |    827658 |    857173 | .          | +            | .          | PB.2       | PB.2.1          |         1 |         4 |
# | chr1         | stuff      | transcript   |    854801 |    859446 | .          | +            | .          | PB.2       | PB.2.1          |         1 |         4 |
# | chr1         | stuff      | transcript   |    834239 |    838441 | .          | +            | .          | PB.1       | PB.1.1          |         1 |         4 |
# | chr1         | stuff      | transcript   |   2556370 |   2563747 | .          | +            | .          | PB.13      | PB.13.2         |         2 |        44 |
# | chr1         | stuff      | transcript   |   3857266 |   3885426 | .          | +            | .          | PB.7       | PB.7.1          |         2 |        44 |
# | chr1         | stuff      | transcript   |   3857266 |   3885424 | .          | +            | .          | PB.12      | PB.12.1         |         2 |        44 |
# | chr1         | stuff      | transcript   |   2556213 |   2563742 | .          | +            | .          | PB.9       | PB.9.1          |         2 |        44 |
# +--------------+------------+--------------+-----------+-----------+------------+--------------+------------+------------+-----------------+-----------+-----------+
# Stranded PyRanges object has 8 rows and 12 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.

# %%
merged2.insert()
